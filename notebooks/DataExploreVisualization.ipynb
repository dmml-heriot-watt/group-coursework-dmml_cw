# %%
import pandas as pd

# Load the Wine Quality dataset
df = pd.read_csv('../data/PreProcessed/MixWine.csv')

# Generate a statistical summary for the dataset
summary = df.describe()

# Print the summary statistics
summary
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# ...

# %% [markdown]
# Statistical Summary: The code calculates a statistical summary of the dataset using the describe() method. This summary provides key statistics for each numerical column in the dataset, such as the mean, standard deviation, minimum, maximum, and quartiles. This summary can give you an initial overview of the central tendencies and the spread of the data.
#
# Count: The "count" row tells you how many data points are available for each numerical column. If there are missing values, columns may have different counts, which can be important to note.
#
# Mean (Average): The "mean" provides the average value for each numerical column. This can give you a sense of the central tendency of the data.
#
# Standard Deviation: The "std" (standard deviation) measures the spread or variability of the data. A higher standard deviation indicates greater variability.
#
# Min and Max: The "min" and "max" values show the minimum and maximum values in each column. This can help you identify the range of values in the data.
#
# 25th, 50th (Median), and 75th Percentiles: These values provide information about the distribution of data. The 25th percentile (1st quartile) represents the value below which 25% of the data falls, while the 75th percentile (3rd quartile) represents the value below which 75% of the data falls. The median (50th percentile) is the middle value of the data. These percentiles help you understand the data's spread and skewness range.
#
# here are detailed descriptions for each attribute:
#
# Fixed Acidity:
#
# Fixed acidity exhibits a small standard deviation, signifying low variability. The range of values spans from a minimum of 3.8 to a maximum of 15.9, indicating a moderate data spread. Moreover, the mean (7.22) and median (7.0) are relatively close, suggesting symmetric data, and there are hints of potential outliers on the higher en
# d.
# Volatile Acidiy:
#
# Volatile acidity shows a moderate standard deviation, suggesting moderate variability. The range of values extends from a minimum of 0.08 to a maximum of 1.58, indicating a moderate data spread. The mean (0.34) and median (0.29) are relatively close, indicating symmetric data, with possible outliers on the higher-value
# side.
# CitricAcid:
#
# Citric acid demonstrates moderate variability with a standard deviation of approximately 0.15. The data has a moderate spread, ranging from a minimum of 0 to a maximum of 1.66. The mean (0.32) and median (0.31) are relatively close, suggesting symmetric data, with possible outliers on the higher-val
#
# e side.
# Residul Sugar:
#
# Residual sugar exhibits moderate to high variability with a standard deviation of about 4.76. The range of values spans from a minimum of 0.6 to a maximum of 65.8, indicating a substantial data spread. The mean (5.44) and median (3.0) are significantly different, suggesting right skewness with likely outliers on the
# higher end.
# Chlorides:
#
# Chlorides display moderate variability with a standard deviation of about 0.035. The data has a moderate spread, ranging from a minimum of 0.009 to a maximum of 0.611. The mean (0.056) and median (0.047) are relatively close, indicating symmetric data, with possible high-va
# lue outliers.
# Free ulfur Dioxide:
#
# Free sulfur dioxide exhibits moderate to high variability with a standard deviation of approximately 17.75. The range of values goes from a minimum of 1 to a maximum of 289, suggesting a moderate to high data spread. The mean (30.53) and median (29.0) are relatively close, indicating symmetric data, with likely outliers on the h
# igher-value side.
# Totl Sulfur Dioxide:
#
# Total sulfur dioxide shows moderate to high variability with a standard deviation of about 56.52. The data has a substantial spread, ranging from a minimum of 6 to a maximum of 440. The mean (115.74) and median (118.0) are relatively close, indicating symmetric data, with likely outliers on th
# e higher-alue side.
# Density:
#
# Density demonstrates low variability with a small standard deviation of about 0.003. The data has a relatively low spread, ranging from a minimum of 0.9871 to a maximum of 1.039. The mean (0.9947) and median (0.99489) are quite close, suggesting a symmetric distribution wit
# h n evident outliers.
# pH:
#
# pH exhibits moderate variability with a standard deviation of about 0.16. The data has a moderate spread, ranging from a minimum of 2.72 to a maximum of 4.01. The mean (3.22) and median (3.21) are relatively close, indicating symmetric data, with possible outlie
# rs on the igher pH side.
# Sulphates:
#
# Sulphates display moderate variability with a standard deviation of approximately 0.15. The data has a moderate spread, ranging from a minimum of 0.22 to a maximum of 2.0. The mean (0.53) and median (0.51) are relatively close, suggesting symmetric data, with possible outliers o
# n the hiher sulphates side.
# Alcohol:
#
# Alcohol content shows moderate variability with a standard deviation of about 1.19. The data has a moderate spread, ranging from a minimum of 8.0 to a maximum of 14.9. The mean (10.49) and median (10.3) are relatively close, indicating symmetric data with no evident outliers.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the Wine Quality dataset
df = pd.read_csv('../data/PreProcessed/MixWine.csv')

# Define the attribute for the bubble chart
x_attribute = 'alcohol'      
y_attribute = 'volatile acidity'
size_attribute = 'quality'          

# Create a bubble chart
plt.figure(figsize=(10, 8))
scatter = plt.scatter(df[x_attribute], df[y_attribute], s=df[size_attribute] * 30, c=df[size_attribute], cmap='coolwarm', alpha=0.8)
plt.title("Wine Quality vs. Alcohol Content and Volatile Acidity")
plt.xlabel("Alcohol Content")
plt.ylabel("Volatile Acidity")
plt.colorbar(label="Wine Quality")
plt.grid(True)
plt.show()

# %% [markdown]
# A bubble chart is a data visualization technique used to display data points in a three-dimensional space, where two axes represent attribute, and the third axis is represented by the size of the bubbles.
#
# The provided code generates a bubble chart using the pandas and matplotlib libraries to visualize relationships between wine quality, alcohol content, and volatile acidity
#
# The X-axis represents "Alcohol Content," which is a numerical attribute.
#
# The Y-axis represents "Volatile Acidity," another numerical attribute.
#
# Bubble Size: The size of each bubble represents the "Wine Quality" of the corresponding wine sample. Larger bubbles indicate higher wine quality, while smaller bubbles indicate lower quality. This allows you to quickly identify wines with different quality levels in the dataset.
#
# Color Mapping: The color of each bubble is determined by the "Wine Quality" as well, and it follows a "coolwarm" color map. This provides an additional visual cue for quality, with cooler colors (e.g., blue) representing lower quality and warmer colors (e.g., red) representing higher quality.
#
# Here are some additional insights from the bubble chart:
#
# The cluster of points in the lower left corner of the plot represents wines with low alcohol content and high volatile acidity. These wines are likely to be of low quality.
#
# The cluster of points in the right side of the plot represents wines with high alcohol content and low volatile acidity. These wines are likely to be of high quality.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Wine Quality dataset
df = pd.read_csv('../data/PreProcessed/MixWine.csv')

# Select only the numeric columns for the correlation matrix
numeric_columns = df.select_dtypes(include=['number'])

# Compute the correlation matrix for numeric columns
correlation_matrix = numeric_columns.corr()

# Create a heatmap of the correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title("Correlation Heatmap of Numeric Attributes in Wine Quality Dataset")
plt.show()

# %% [markdown]
# Heatmap is a visual representation of the correlations between pairs of attributes in a dataset. It uses colors to represent the strength and direction of the correlations. Here's how to interpret the elements of a correlation heatmap:
#
# Color Scale: The heatmap uses a color scale to represent correlation values. In these color scales, positive correlations are typically shown in warm colors (e.g., red or orange), while negative correlations are in cool colors (e.g., blue).
#
# Cells: Each cell in the heatmap represents the correlation between two attributes. The cell's color intensity indicates the strength of the correlation, with darker colors indicating stronger correlations. The color indicates the direction of the correlation (positive or negative).
#
# Annotations: Numeric values inside the cells represent the correlation coefficients. These coefficients range from -1 to 1. A value of 1 indicates a perfect positive correlation, -1 indicates a perfect negative correlation, and 0 indicates no correlation. The closer the value is to 1 or -1, the stronger the correlation.
#
# Diagonal Line: The diagonal line from the top-left to the bottom-right of the heatmap represents the correlation of each variable with itself. It will always be 1, as a variable is perfectly correlated with itself.
#
# Heatmap in the context of the Wine Quality dataset:
# Strong Positive Correlation: If two attributes have a strong positive correlation (e.g., a correlation coefficient close to 1), they tend to increase together. For example, if you find a dark red cell between "alcohol" and "density," it suggests that as alcohol content increases, density also tends to increase.
#
# Strong Negative Correlation: A strong negative correlation (e.g., a correlation coefficient close to -1) indicates that two attributes tend to move in opposite directions. For instance, if "pH" has a dark blue cell with "fixed acidity," it suggests that as pH increases, fixed acidity tends to decrease.
#
# No Correlation: If the cell is a pale color or close to white and the correlation coefficient is near 0, it suggests no significant linear relationship between the two attributes.
#
# Here are some additional insights from the bubble chart:
#
# Alcohol vs. density
# The negative correlation between alcohol and density suggests that wines with higher alcohol content tend to be less dense.
#
# Alcohol vs. quality
# The positive correlation between alcohol and quality suggests that wines with higher alcohol content tend to be of higher quality.
#
# Fixed acidity vs. density
# The positive correlation between fixed acidity and density suggests that wines with higher fixed acidity tend to be more dense.
#
# Residual sugar vs. density
# The positive correlation between residual sugar and density suggests that wines with higher residual sugar tend to be more dense.
#
# Free sulfur dioxide vs. total sulfur dioxide
# The positive correlation between free sulfur dioxide and total sulfur dioxide suggests that wines with higher free sulfur dioxide levels also tend to have higher total sulfur dioxide levels.
#
# Alcohol vs. citric acid
# The weak correlation between alcohol and citric acid suggests that there is little to no relationship between these two variables.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Wine Quality dataset
df = pd.read_csv('MixWine.csv')

# Select only the numeric columns for box plots
numeric_columns = df.select_dtypes(include=['number'])

# Set the figure size
plt.figure(figsize=(15, 10))

# Create separate box plots for each numeric attribute
for i, col in enumerate(numeric_columns.columns):
    plt.subplot(3, 4, i + 1)  # Create a 3x4 grid of subplots
    sns.boxplot(x=df[col])
    plt.title(f"Box Plot of {col}")
    plt.xticks(rotation=45)  # Rotate x-axis labels for better readability

plt.tight_layout()  # Ensure proper spacing between subplots
plt.show()

# %% [markdown]
# Box plots are valuable tools for data exploration and initial understanding of the data's characteristics. They complement other summary statistics and visualization techniques.
#
# Median:
#
# The line inside the box represents the median of the data. It's the middle value when the data is sorted in ascending order.
# The median provides a measure of central tendency, indicating where the data tends to clust
# eox (Interquartile Range,IR):
#
# The box itself represents the interquartile range (IQR), which contains the middle 50% of the data.
# The IQR is calculated as the difference between the 75th percentile (Q3) and the 25th percentile (Q1).
# It provides information about the spread of the centr
# al data.
#  he Box):
#
# The whiskers extend from the box to the minimum and maximum values within a calculated range.
# They give an idea of the data's spread beyond the central 50%.
# Any data points outside the whiskers are considered potent
# ial outlisde Whiskers):
#
# Outliers are individual data points that fall significantly outside the range covered by the whiskers.
# They can be indicative of unusual or extreme observations in the dataset.
# Outliers may warrant further investigation to determine if they are genuine data
#
# Skewness:
#
# The shape of the box plot can provide insights into the data's skewness (asymmetry).
# If the box is longer on the right side (Q3 to the maximum), it suggests positive skew (right-skewed distribution).
# If the box is longer on the left side (Q1 to the minimum), it suggests negative skew (left-skewed distributi
#
# Here are some additional insights from the box plot:
#
# Residual Sugar:
# The median residual sugar level is 3. This means that 50% of the wines in the dataset have residual sugar levels below 3, and 50% of the wines in the dataset have residual sugar levels above 3.
# Overall, the summary of residual sugar suggests that there is a wide range of residual sugar levels in the dataset, with most wines having residual sugar levels between 1.8 and 8.1. A few outliers have very high residual sugar levels.
# Chlorides:
# The median chloride level is 0.047. This means that 50% of the wines in the dataset have chloride levels below 0.047, and 50% of the wines in the dataset have chloride levels above 0.047.
# The distribution of chlorides in the dataset is skewed to the right, with a few outliers on the high end.
# Overall, the summary of chlorides suggests that there is a wide range of chloride levels in the dataset, with most wines having chloride levels between 0.038 and 0.065. A few outliers have very high chloride levels.
#
# Alcohol:
# The median alcohol level is 10.3%. This means that 50% of the wines in the dataset have alcohol levels below 10.3%, and 50% of the wines in the dataset have alcohol levels above 10.3%.
#
# on). points or errors.
